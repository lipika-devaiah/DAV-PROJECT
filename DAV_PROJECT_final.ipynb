# %% [markdown]
# <a href="https://colab.research.google.com/github/lipika-devaiah/DAV-PROJECT/blob/main/DAV_PROJECT_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/restaurants.csv')
df
# Out:
#                                 Name  \
# 0                              Local
# 1                      The G.T. ROAD
# 2                            Tamasha
# 3                  The Junkyard Cafe
# 4     Chili's American Grill and Bar
# ...                              ...
# 6588                   Shree Rathnam
# 6589                     Cafe Delish
# 6590                     3 K Resorts
# 6591                       Dovka Bar
# 6592                     Urban Vibes
#
#                                                Location           Locality  \
# 0          Scindia House,Connaught Place, Central Delhi      Central Delhi
# 1                M-Block,Connaught Place, Central Delhi      Central Delhi
# 2                        Connaught Place, Central Delhi      Central Delhi
# 3                        Connaught Place, Central Delhi      Central Delhi
# 4                M-Block,Connaught Place, Central Delhi      Central Delhi
# ...                                                 ...                ...
# 6588                 Wave Mall,BRS Nagar, West Ludhiana      West Ludhiana
# 6589          Radisson Blu,Rajguru Nagar, West Ludhiana      West Ludhiana
# 6590                           BRS Nagar, West Ludhiana      West Ludhiana
# 6591  Nirvana Hotel Banquets Club,PAU, Central Ludhiana   Central Ludhiana
# 6592                         Aggar Nagar, West Ludhiana      West Ludhiana
#
#           City                                            Cuisine  Rating  \
# 0        Delhi           North Indian,  Finger Food,  Continental     4.1
# 1        Delhi                                       North Indian     4.3
# 2        Delhi  Finger Food,  North Indian,  Italian,  Contine...     4.2
# 3        Delhi  North Indian,  Mediterranean,  Asian,  Italian...     4.2
# 4        Delhi                       Mexican,  American,  Italian     4.4
# ...        ...                                                ...     ...
# 6588  Ludhiana                                       South Indian     4.1
# 6589  Ludhiana  Multi-Cuisine,  North Indian,  Continental,  A...     4.4
# 6590  Ludhiana                                       North Indian     1.0
# 6591  Ludhiana               North Indian,  Chinese,  Finger Food     4.3
# 6592  Ludhiana  Multi-Cuisine,  North Indian,  Italian,  Chine...     3.8
#
#       Votes  Cost
# 0      2415  2000
# 1      2363  1500
# 2      5016  2000
# 3      2821  1800
# 4      1094  2000
# ...     ...   ...
# 6588     20   600
# 6589     48  3100
# 6590      1  1100
# 6591      3  1500
# 6592     12  2000
#
# [6593 rows x 8 columns]

# %%
df.head(5)
# Out:
#                              Name  \
# 0                           Local
# 1                   The G.T. ROAD
# 2                         Tamasha
# 3               The Junkyard Cafe
# 4  Chili's American Grill and Bar
#
#                                        Location        Locality   City  \
# 0  Scindia House,Connaught Place, Central Delhi   Central Delhi  Delhi
# 1        M-Block,Connaught Place, Central Delhi   Central Delhi  Delhi
# 2                Connaught Place, Central Delhi   Central Delhi  Delhi
# 3                Connaught Place, Central Delhi   Central Delhi  Delhi
# 4        M-Block,Connaught Place, Central Delhi   Central Delhi  Delhi
#
#                                              Cuisine  Rating  Votes  Cost
# 0           North Indian,  Finger Food,  Continental     4.1   2415  2000
# 1                                       North Indian     4.3   2363  1500
# 2  Finger Food,  North Indian,  Italian,  Contine...     4.2   5016  2000
# 3  North Indian,  Mediterranean,  Asian,  Italian...     4.2   2821  1800
# 4                       Mexican,  American,  Italian     4.4   1094  2000

# %%
df.info
# Out:
# <bound method DataFrame.info of                                 Name  \
# 0                              Local
# 1                      The G.T. ROAD
# 2                            Tamasha
# 3                  The Junkyard Cafe
# 4     Chili's American Grill and Bar
# ...                              ...
# 6588                   Shree Rathnam
# 6589                     Cafe Delish
# 6590                     3 K Resorts
# 6591                       Dovka Bar
# 6592                     Urban Vibes
#
#                                                Location           Locality  \
# 0          Scindia House,Connaught Place, Central Delhi      Central Delhi
# 1                M-Block,Connaught Place, Central Delhi      Central Delhi
# 2                        Connaught Place, Central Delhi      Central Delhi
# 3                        Connaught Place, Central Delhi      Central Delhi
# 4                M-Block,Connaught Place, Central Delhi      Central Delhi
# ...                                                 ...                ...
# 6588                 Wave Mall,BRS Nagar, West Ludhiana      West Ludhiana
# 6589          Radisson Blu,Rajguru Nagar, West Ludhiana      West Ludhiana
# 6590                           BRS Nagar, West Ludhiana      West Ludhiana
# 6591  Nirvana Hotel Banquets Club,PAU, Central Ludhiana   Central Ludhiana
# 6592                         Aggar Nagar, West Ludhiana      West Ludhiana
#
#           City                                            Cuisine  Rating  \
# 0        Delhi           North Indian,  Finger Food,  Continental     4.1
# 1        Delhi                                       North Indian     4.3
# 2        Delhi  Finger Food,  North Indian,  Italian,  Contine...     4.2
# 3        Delhi  North Indian,  Mediterranean,  Asian,  Italian...     4.2
# 4        Delhi                       Mexican,  American,  Italian     4.4
# ...        ...                                                ...     ...
# 6588  Ludhiana                                       South Indian     4.1
# 6589  Ludhiana  Multi-Cuisine,  North Indian,  Continental,  A...     4.4
# 6590  Ludhiana                                       North Indian     1.0
# 6591  Ludhiana               North Indian,  Chinese,  Finger Food     4.3
# 6592  Ludhiana  Multi-Cuisine,  North Indian,  Italian,  Chine...     3.8
#
#       Votes  Cost
# 0      2415  2000
# 1      2363  1500
# 2      5016  2000
# 3      2821  1800
# 4      1094  2000
# ...     ...   ...
# 6588     20   600
# 6589     48  3100
# 6590      1  1100
# 6591      3  1500
# 6592     12  2000
#
# [6593 rows x 8 columns]>

# %%
df.describe()
# Out:
#             Rating        Votes         Cost
# count  6593.000000  6593.000000  6593.000000
# mean      4.088200   119.420143  1102.798271
# std       0.670031   261.849704   716.935212
# min       1.000000     1.000000   100.000000
# 25%       3.900000     6.000000   500.000000
# 50%       4.200000    31.000000   900.000000
# 75%       4.400000   115.000000  1500.000000
# max       5.000000  5016.000000  8000.000000

# %%
df.shape
# Out:
# (6593, 8)

# %%
df.columns
# Out:
# Index(['Name', 'Location', 'Locality', 'City', 'Cuisine', 'Rating', 'Votes',
#        'Cost'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Name        0
# Location    0
# Locality    0
# City        0
# Cuisine     0
# Rating      0
# Votes       0
# Cost        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 3

# %%
df.drop_duplicates(inplace=True)

# %%
#CITY COUNT
df['City'].value_counts()
# Out:
# Bangalore     1017
# Delhi          734
# Mumbai         727
# Kolkata        711
# Hyderabad      589
# Ahmedabad      414
# Chennai        388
# Pune           351
# Jaipur         268
# Chandigarh     264
# Indore         204
# Gurgaon        184
# Noida          146
# Vadodara        91
# Lucknow         80
# Agra            75
# Nagpur          66
# Surat           64
# Ludhiana        62
# Goa             60
# Ghaziabad       50
# Udaipur         43
# Kochi            2
# Name: City, dtype: int64

# %%
# top 5 restaurants with highest ratings
df1 = df['Rating'].value_counts().sort_values(ascending=False).head(5)
df1
# Out:
# 4.3    811
# 4.2    698
# 4.4    681
# 4.5    576
# 4.1    575
# Name: Rating, dtype: int64

# %%
df2 = df['Rating'].max()
df2
# Out:
# 5.0

# %%
df3 = df.loc[df['Rating'] ==  df2]
df3
# Out:
#                                Name                         Location  \
# 72                   Mughal-E-Hazam   Connaught Place, Central Delhi
# 84                        Bistro 55         Paharganj, Central Delhi
# 115           Thalassery Restaurant       Rajinder Nagar, West Delhi
# 134                  The Waffle Co.       Rajinder Nagar, West Delhi
# 149                       Bake Club     East Patel Nagar, West Delhi
# ...                             ...                              ...
# 6555                  Captain Sam's   Gurdev Nagar, Central Ludhiana
# 6556                  Hotel Riyasat  Industrial Area, South Ludhiana
# 6557  Basant Ice Cream Cafe & Foods     Sarabha Nagar, West Ludhiana
# 6559                        Karim's     Sarabha Nagar, West Ludhiana
# 6574             The Crispy Hawkers         BRS Nagar, West Ludhiana
#
#                Locality      City  \
# 72        Central Delhi     Delhi
# 84        Central Delhi     Delhi
# 115          West Delhi     Delhi
# 134          West Delhi     Delhi
# 149          West Delhi     Delhi
# ...                 ...       ...
# 6555   Central Ludhiana  Ludhiana
# 6556     South Ludhiana  Ludhiana
# 6557      West Ludhiana  Ludhiana
# 6559      West Ludhiana  Ludhiana
# 6574      West Ludhiana  Ludhiana
#
#                                                 Cuisine  Rating  Votes  Cost
# 72                                         North Indian     5.0      1  1200
# 84    Multi-Cuisine,  North Indian,  Italian,  Chine...     5.0      2   500
# 115                  North Indian,  Chinese,  Fast Food     5.0      1   800
# 134                          Desserts,  Waffle,  Shakes     5.0      1   400
# 149     Bakery and Confectionary,  Desserts,  Fast Food     5.0      1   500
# ...                                                 ...     ...    ...   ...
# 6555                                  Fast Food,  Pizza     5.0      2   800
# 6556                 North Indian,  Oriental ,  Mughlai     5.0      3  2600
# 6557                 Chinese,  North Indian,  Ice Cream     5.0      1   900
# 6559                                            Mughlai     5.0      1  1400
# 6574                                          Fast Food     5.0      1   300
#
# [475 rows x 8 columns]

# %%
df1.plot(kind="bar")
plt.title("The Top Ten Rating")
plt.xlabel("Rating")
plt.ylabel('Count')
plt.show()

# %%
#distribution of restaurants across cities
plt.figure(figsize=(15,8))
sns.countplot(y = 'City', data = df, order = df['City'].value_counts().index, palette = 'viridis')
plt.title('Distribution of Restaurants across Cities in India')
plt.xlabel('Number of Restaurants')
plt.ylabel('City')
plt.show()

# %%
#voting distribution
plt.figure(figsize=(8,6))
plt.hist(df['Votes'], color='orange')
plt.title('Distribution of Restaurant Votes in India')
plt.xlabel('Votes')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# TOP CUISINS IN INDIA

# %%
#GROUPING THE DATA BY CITY AND CUISINE AND COUNTING THE RESTAURANTS

df_cuisine = df.groupby(['City','Cuisine'])['Name'].count().reset_index()
df_cuisine
# Out:
#           City                   Cuisine  Name
# 0         Agra  Bakery and Confectionary     1
# 1         Agra                   Chinese     1
# 2         Agra         Chinese,  Seafood     1
# 3         Agra            Chinese,  Thai     2
# 4         Agra              Coffee,  Tea     1
# ...        ...                       ...   ...
# 3537  Vadodara           Pizza,  Italian     3
# 3538  Vadodara                    Shakes     1
# 3539  Vadodara              South Indian     2
# 3540  Vadodara               Street Food     1
# 3541  Vadodara   Street Food,  Fast Food     1
#
# [3542 rows x 3 columns]

# %%
#TOP CUISINES FOR EACH CITY
df_top_cuisine = df_cuisine.loc[df_cuisine.groupby('City')['Name'].idxmax()]
df_top_cuisine
# Out:
#             City                                            Cuisine  Name
# 6           Agra                                          Fast Food     6
# 271    Ahmedabad                                       South Indian    23
# 545    Bangalore                                  Mithai,  Desserts    67
# 771   Chandigarh                                          Fast Food    16
# 1005     Chennai  Multi-Cuisine,  North Indian,  Chinese,  South...    26
# 1415       Delhi                             North Indian,  Mughlai    33
# 1478   Ghaziabad                             North Indian,  Chinese     7
# 1521         Goa  Multi-Cuisine,  North Indian,  South Indian,  ...    10
# 1682     Gurgaon                      Street Food,  Tea,  Fast Food    10
# 1912   Hyderabad                             North Indian,  Chinese    39
# 2053      Indore                             North Indian,  Chinese    27
# 2128      Jaipur                                        Finger Food    12
# 2249       Kochi                Continental,  North Eastern,  Asian     1
# 2370     Kolkata                                Fast Food,  Tibetan    58
# 2589     Lucknow                             North Indian,  Chinese     7
# 2643    Ludhiana                             North Indian,  Chinese     4
# 2755      Mumbai                                          Fast Food    33
# 3069      Nagpur                                          Fast Food    10
# 3175       Noida                             North Indian,  Mughlai     9
# 3323        Pune                             North Indian,  Chinese    25
# 3416       Surat                                          Fast Food     6
# 3457     Udaipur                                        Finger Food     3
# 3498    Vadodara                                          Fast Food     7

# %%
plt.figure(figsize=(22,12))
plt.bar(df_top_cuisine['City'], df_top_cuisine['Cuisine'], color='blue')
plt.title('Top cuisines for each city', fontsize=18)
plt.xlabel('city')
plt.ylabel('Number of restaurants')

plt.show()

# %% [markdown]
# COMPARISON OF AVERAGE RATINGS ACROSS CITIES

# %%
#create a dataframe with average rating by city
df_rating = df.groupby('City')['Rating'].mean().reset_index()
df_rating
# Out:
#           City    Rating
# 0         Agra  4.238667
# 1    Ahmedabad  4.202899
# 2    Bangalore  4.029931
# 3   Chandigarh  4.137500
# 4      Chennai  4.025258
# 5        Delhi  4.176567
# 6    Ghaziabad  4.086000
# 7          Goa  4.153333
# 8      Gurgaon  4.308696
# 9    Hyderabad  4.040917
# 10      Indore  3.790686
# 11      Jaipur  4.092910
# 12       Kochi  3.400000
# 13     Kolkata  3.990590
# 14     Lucknow  4.016250
# 15    Ludhiana  3.912903
# 16      Mumbai  4.180330
# 17      Nagpur  4.136364
# 18       Noida  4.193836
# 19        Pune  4.078632
# 20       Surat  3.964062
# 21     Udaipur  4.072093
# 22    Vadodara  4.131868

# %%
#sorting the dataframe by rating
df_rating = df_rating.sort_values('Rating').reset_index()
df_rating
# Out:
#     index        City    Rating
# 0      12       Kochi  3.400000
# 1      10      Indore  3.790686
# 2      15    Ludhiana  3.912903
# 3      20       Surat  3.964062
# 4      13     Kolkata  3.990590
# 5      14     Lucknow  4.016250
# 6       4     Chennai  4.025258
# 7       2   Bangalore  4.029931
# 8       9   Hyderabad  4.040917
# 9      21     Udaipur  4.072093
# 10     19        Pune  4.078632
# 11      6   Ghaziabad  4.086000
# 12     11      Jaipur  4.092910
# 13     22    Vadodara  4.131868
# 14     17      Nagpur  4.136364
# 15      3  Chandigarh  4.137500
# 16      7         Goa  4.153333
# 17      5       Delhi  4.176567
# 18     16      Mumbai  4.180330
# 19     18       Noida  4.193836
# 20      1   Ahmedabad  4.202899
# 21      0        Agra  4.238667
# 22      8     Gurgaon  4.308696

# %%
#pie chart
plt.figure(figsize=(8,8))
plt.pie(df_rating['Rating'], labels=df_rating['City'], autopct='%1.1f%%', explode=[0.1]*len(df_rating))
plt.title('Comparison of Average Ratings Across city')
plt.show()

# %% [markdown]
# COMPARISON OF AVERAGE DINING COST ACROSS CITES

# %%
#creating a dataframe with avg cost and city
df_cost_city = df.groupby('City')['Cost'].mean().reset_index()
df_cost_city
# Out:
#           City         Cost
# 0         Agra  1320.000000
# 1    Ahmedabad   777.294686
# 2    Bangalore   924.288518
# 3   Chandigarh   984.848485
# 4      Chennai   937.113402
# 5        Delhi  1526.634877
# 6    Ghaziabad  1374.000000
# 7          Goa  1480.000000
# 8      Gurgaon  1610.326087
# 9    Hyderabad  1114.940577
# 10      Indore  1017.892157
# 11      Jaipur  1149.253731
# 12       Kochi   650.000000
# 13     Kolkata   880.897472
# 14     Lucknow  1243.750000
# 15    Ludhiana  1241.935484
# 16      Mumbai  1271.733150
# 17      Nagpur  1056.060606
# 18       Noida  1399.315068
# 19        Pune  1096.723647
# 20       Surat   709.375000
# 21     Udaipur  1120.930233
# 22    Vadodara   612.087912

# %%
#sorting the dataframe by cost
df_cost_city = df_cost_city.sort_values('Cost').reset_index()
df_cost_city
# Out:
#     index        City         Cost
# 0      22    Vadodara   612.087912
# 1      12       Kochi   650.000000
# 2      20       Surat   709.375000
# 3       1   Ahmedabad   777.294686
# 4      13     Kolkata   880.897472
# 5       2   Bangalore   924.288518
# 6       4     Chennai   937.113402
# 7       3  Chandigarh   984.848485
# 8      10      Indore  1017.892157
# 9      17      Nagpur  1056.060606
# 10     19        Pune  1096.723647
# 11      9   Hyderabad  1114.940577
# 12     21     Udaipur  1120.930233
# 13     11      Jaipur  1149.253731
# 14     15    Ludhiana  1241.935484
# 15     14     Lucknow  1243.750000
# 16     16      Mumbai  1271.733150
# 17      0        Agra  1320.000000
# 18      6   Ghaziabad  1374.000000
# 19     18       Noida  1399.315068
# 20      7         Goa  1480.000000
# 21      5       Delhi  1526.634877
# 22      8     Gurgaon  1610.326087

# %%
#plotting the horizontal  bar graph for the comparison of avg cost with cities
plt.figure(figsize=(12,8))
plt.barh(df_cost_city['City'], df_cost_city['Cost'], color='#FFC107')
plt.title('comparison of average cost across cities', fontsize=18)
plt.xlabel('Average cost')
plt.ylabel('City')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()
